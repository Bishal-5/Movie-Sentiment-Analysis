# %%
# Google Drive Mount/Access
from google.colab import drive # For accessing the google drive files
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Import Modules

# %%
import pandas as pd # For Data Analysis & Manipulation in a tabular format
import matplotlib.pyplot as plt # Data Visualization to create plot & graph [fine-grained control]
import plotly.express as px # Data Visualization to create plot & graph [Quickly & Easily]
import seaborn as sns # Statistical data exploration with beautiful & informative plots
import warnings # Managing and Handling warnings in code
warnings.filterwarnings('ignore') # To ignore all warnings

# %% [markdown]
# Library Install

# %%
pip install pyspellchecker  # Spell checking functionality
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.8/6.8 MB 37.0 MB/s eta 0:00:00
# ...

# %% [markdown]
# Import Adipurush_Tweets' form Google Drive

# %%
# 'Adipurush_Tweets' File Import form Google Drive
df = pd.read_csv('/content/drive/MyDrive/DataScience Training/Project/Adipurush_Tweets.csv')
# 'df' is the Original DataFrame of 'Adipurush_Tweets'

# %%
df # Printing the DataFrame
# Out:
#                   Date Created  Number of Likes  Source of Tweet  \
# 0    2023-06-30 09:21:00+00:00                0              NaN
# 1    2023-06-30 09:20:57+00:00                0              NaN
# 2    2023-06-30 09:20:22+00:00                0              NaN
# 3    2023-06-30 09:20:00+00:00                3              NaN
# 4    2023-06-30 09:15:22+00:00                3              NaN
# ..                         ...              ...              ...
# 994  2023-06-29 07:07:12+00:00               14              NaN
# 995  2023-06-29 07:06:59+00:00                0              NaN
# 996  2023-06-29 07:06:35+00:00                0              NaN
# 997  2023-06-29 07:06:23+00:00                0              NaN
# 998  2023-06-29 07:05:59+00:00                1              NaN
#
#                                                 Tweets
# 0    #ENGvAUS #ENGvsAUS #AUSvENG #AUSvsENG #Adipuru...
# 1    Now Playing!! Book Your Ticket Now!! 🎥🍿🎟️\n@go...
# ...

# %% [markdown]
# Line Graph From Adipurush_Tweets DataSheet

# %%
df_sorted_date = df.sort_values('Date Created') # Sorts the data frame
plt.figure(figsize=[15,7],) # Figure/Size for the Graph Image [width: 15 ; height: 10]
plt.plot(df_sorted_date['Date Created'], df_sorted_date['Number of Likes']) # Plots the data points
plt.xlabel('Date Created') # Sets the label for the X-axis
plt.ylabel('Number of Likes') # Sets the label for the Y-axis
plt.title('Number of Likes over Time') # Sets the title of the plot
plt.show() # Displays the plot on the screen

# %% [markdown]
# Scatter Graph From Adipurush_Tweets DataSheet

# %%
plt.figure(figsize=[12,5],) # Figure/Size for the Graph Image [width: 12 ; height: 5]
# Create scatter plot of values from the columns 'Date Created' & 'Number of Likes'
plt.scatter(df_sorted_date['Date Created'], df_sorted_date['Number of Likes'])
plt.xlabel('Date Created') # Sets the label for the X-axis
plt.ylabel('Number of Likes') # Sets the label for the Y-axis
plt.title('Number of Likes over Time') # Sets the title of the plot
plt.show() # Displays the plot on the screen

# %%
# 'px.scatter' from 'Plotly Express' to create a scatter plot using the 'df_sorted_date' DataFrame
fig = px.scatter(df_sorted_date, x='Date Created', y='Number of Likes', title='Number of Likes over Time')
# 'update_layout' method of the 'fig' object to further customize the plot layout
fig.update_layout(xaxis=dict(title='Date Created'), yaxis=dict(title='Number of Likes'))
fig.show() # Displays the plot on the screen
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# Structure of the Adipurush_Tweets DataSheet

# %%
print(df.shape) # Understand the overall size & shape of the DataFrame [No. of row & column]
print(df.columns) # List of column names in the DataFrame
print(df.duplicated().sum()) # Total no. of row in the DataFrame that contain duplicate data
# Out:
# (999, 4)
# Index(['Date Created', 'Number of Likes', 'Source of Tweet', 'Tweets'], dtype='object')
# 0

# %%
df = df.drop_duplicates() # Removes duplicate rows from the DataFrame

# %%
df.isnull().sum() # Calculates the no. of missing values in each column of the DataFrame
# Out:
# Date Created         0
# Number of Likes      0
# Source of Tweet    999
# Tweets               0
# dtype: int64

# %%
# Axis=1 (Drop a column) & Axis=0 (Drop a row)
df = df.drop('Source of Tweet',axis=1) # To modify the DataFrame by dropping a specific column

# %%
df # Printing the updated DataFrame now
# Out:
#                   Date Created  Number of Likes  \
# 0    2023-06-30 09:21:00+00:00                0
# 1    2023-06-30 09:20:57+00:00                0
# 2    2023-06-30 09:20:22+00:00                0
# 3    2023-06-30 09:20:00+00:00                3
# 4    2023-06-30 09:15:22+00:00                3
# ..                         ...              ...
# 994  2023-06-29 07:07:12+00:00               14
# 995  2023-06-29 07:06:59+00:00                0
# 996  2023-06-29 07:06:35+00:00                0
# 997  2023-06-29 07:06:23+00:00                0
# 998  2023-06-29 07:05:59+00:00                1
#
#                                                 Tweets
# 0    #ENGvAUS #ENGvsAUS #AUSvENG #AUSvsENG #Adipuru...
# 1    Now Playing!! Book Your Ticket Now!! 🎥🍿🎟️\n@go...
# 2                               @ponilemova #Adipurush
# 3    Adipurush VS 72 Hoorain VS The Kerala Story Co...
# 4               ST: #Adipurush https://t.co/lsGKcgQuKL
# ...

# %%
# Prints a information of the DataFrame including Data types [Dtype], Memory Usage, Non-Null Count, D-type counts, Null counts
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 999 entries, 0 to 998
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Date Created     999 non-null    object
#  1   Number of Likes  999 non-null    int64
#  2   Tweets           999 non-null    object
# dtypes: int64(1), object(2)
# memory usage: 23.5+ KB

# %%
# Gives a statistical summary of dataframe such as the mean, standard deviation, min, max, and quantiles each column
df.describe()
# Out:
#        Number of Likes
# count       999.000000
# mean         67.235235
# std         252.667896
# min           0.000000
# 25%           0.000000
# 50%           2.000000
# 75%          13.000000
# max        3835.000000

# %%
df.nunique() # To get the number of unique values in a column of DataFrame
# Out:
# Date Created       990
# Number of Likes    178
# Tweets             991
# dtype: int64

# %%
# Sort the DataFrame in descending order based on the 'Number of Likes'
df_sorted = df.sort_values(by='Number of Likes', ascending=False)
# Retrieve & display the first 10 row of the 'df_sorted' DataFrame.
df_sorted.head(10)
# This convert the values in the 'Date Created' column to 'datetime' objects.
df['Date Created'] = pd.to_datetime(df['Date Created'])

# %%
import re # For regular expression operations
import string # For string manipulation
from tqdm.notebook import tqdm # For progress bar visualization
from datetime import datetime # For working with dates and times
import dateutil.parser # For parsing dates from various formats

# %%
import nltk # For natural language processing tasks
from spellchecker import SpellChecker # For spell checking
from nltk.sentiment.vader import SentimentIntensityAnalyzer as SIA # For sentiment analysis

# %%
from wordcloud import WordCloud, ImageColorGenerator # For creating word clouds
from nltk.corpus import stopwords # For removing common words (The, and, is etc)
import random # For generating random numbers

# %%
nltk.download('vader_lexicon') # Download the VADER lexicon for sentiment analysis
nltk.download('stopwords') # Download the stopwords for removing common words
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
languages = stopwords.fileids() # Get the list of supported languages

# Print the number of supported languages
print("Number of supported languages:", len(languages))

# Print the list of supported languages
print("Supported languages:", languages)
# Out:
# Number of supported languages: 29
# Supported languages: ['arabic', 'azerbaijani', 'basque', 'bengali', 'catalan', 'chinese', 'danish', 'dutch', 'english', 'finnish', 'french', 'german', 'greek', 'hebrew', 'hinglish', 'hungarian', 'indonesian', 'italian', 'kazakh', 'nepali', 'norwegian', 'portuguese', 'romanian', 'russian', 'slovene', 'spanish', 'swedish', 'tajik', 'turkish']

# %%
# splitting text into smaller units, such as words, sentences, or n-grams
from nltk.tokenize import TweetTokenizer # For tokenizing tweets

# %%
english_stopwords = stopwords.words('english') # Get the list of stopwords for English
hinglish_stopwords = stopwords.words('hinglish') # Get the list of stopwords for Hinglish

# %%
def clean_tweet(tweet):
    # Remove URLs, hashtags, mentions, and special characters
    tweet = re.sub(r"http\S+|www\S+|@\w+|#\w+", "", tweet)
    tweet = re.sub(r"[^\w\s]", "", tweet)

    # Tokenize the tweet
    tokenizer = TweetTokenizer(preserve_case=False, reduce_len=True, strip_handles=True)
    tokens = tokenizer.tokenize(tweet)

    # Remove stopwords for English and Hinglish
    tokens = [token for token in tokens if token not in english_stopwords and token not in hinglish_stopwords]

    # Remove punctuation and convert to lowercase
    tokens = [token.translate(str.maketrans('', '', string.punctuation)) for token in tokens]
    tokens = [token.lower() for token in tokens]

    # Join tokens back into a string
    cleaned_tweet = ' '.join(tokens)

    return cleaned_tweet

# %%
# Apply the clean_tweet function to each row of the 'Tweets' column
df['Cleaned_Tweets'] = df['Tweets'].apply(clean_tweet)

# %%
df # Printing the updated DataFrame now
# Out:
#                  Date Created  Number of Likes  \
# 0   2023-06-30 09:21:00+00:00                0
# 1   2023-06-30 09:20:57+00:00                0
# 2   2023-06-30 09:20:22+00:00                0
# 3   2023-06-30 09:20:00+00:00                3
# 4   2023-06-30 09:15:22+00:00                3
# ..                        ...              ...
# 994 2023-06-29 07:07:12+00:00               14
# 995 2023-06-29 07:06:59+00:00                0
# 996 2023-06-29 07:06:35+00:00                0
# 997 2023-06-29 07:06:23+00:00                0
# 998 2023-06-29 07:05:59+00:00                1
#
#                                                 Tweets  \
# 0    #ENGvAUS #ENGvsAUS #AUSvENG #AUSvsENG #Adipuru...
# 1    Now Playing!! Book Your Ticket Now!! 🎥🍿🎟️\n@go...
# 2                               @ponilemova #Adipurush
# 3    Adipurush VS 72 Hoorain VS The Kerala Story Co...
# 4               ST: #Adipurush https://t.co/lsGKcgQuKL
# ..                                                 ...
# ...

# %%
def clean_text(text):
    text = text.lower() # Convert text to lowercase
    return text.strip() # Remove leading and trailing whitespaces

# %%
# Apply the clean_text function to each row of the 'Cleaned_Tweets' column
df.Cleaned_Tweets = df.Cleaned_Tweets.apply(lambda x: clean_text(x))

# %%
def tokenization(text):
    tokens = re.split('W+',text) # Split text into words
    return tokens

# %%
# Apply the 'tokenization' function to each tweet in the 'Cleaned_Tweets' column
df.Cleaned_Tweets = df.Cleaned_Tweets.apply(lambda x: tokenization(x))

# %%
from nltk.stem import WordNetLemmatizer # For lemmatizing words
wordnet_lemmatizer = WordNetLemmatizer() # Create an instance of WordNetLemmatizer

# %%
nltk.download('wordnet') # Download the WordNet lemmatizer
nltk.download('omw-1.4') # Download the WordNet lemmatizer
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# True

# %%
def lemmatizer(text):
  # Lemmatize each word in the text
    lemm_text = "".join([wordnet_lemmatizer.lemmatize(word) for word in text])
    return lemm_text

# %%
# Apply the 'lemmatizer' function to each tweet in the 'Cleaned_Tweets' column
df.Cleaned_Tweets = df.Cleaned_Tweets.apply(lambda x: lemmatizer(x))

# %%
def remove_digits(text):
    clean_text = re.sub(r"\b[0-9]+\b\s*", "", text) # Remove digits
    return(text)

# %%
# Apply the 'remove_digits' function to each tweet in the 'Cleaned_Tweets' column
df.Cleaned_Tweets = df.Cleaned_Tweets.apply(lambda x: remove_digits(x))

# %%
def remove_digits1(sample_text):
  # Remove digits
    clean_text = " ".join([w for w in sample_text.split() if not w.isdigit()])
    return(clean_text)

# %%
# Apply the 'remove_digits1' function to each tweet in the 'Cleaned_Tweets' column
df.Cleaned_Tweets = df.Cleaned_Tweets.apply(lambda x: remove_digits1(x))

# %%
pip install langdetect # For language detection
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 981.5/981.5 kB 11.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for langdetect: filename=langdetect-1.0.9-py3-none-any.whl size=993227 sha256=32fa35bf9b287de373f24e523cb3cbc2d4ff505b4ae07c960f3d6f2fd23b0bff
#   Stored in directory: /root/.cache/pip/wheels/95/03/7d/59ea870c70ce4e5a370638b5462a7711ab78fba2f655d05106
# Successfully built langdetect
# ...

# %%
from langdetect import detect # For language detection

def detect_language(text):
    try:
        lang = detect(text) # Detect language
        return lang
    except:
        return None
# Apply the function to the 'Cleaned_Tweets' column
df['Language'] = df['Cleaned_Tweets'].apply(detect_language)

# %%
df # Printing the updated DataFrame now
# Out:
#                  Date Created  Number of Likes  \
# 0   2023-06-30 09:21:00+00:00                0
# 1   2023-06-30 09:20:57+00:00                0
# 2   2023-06-30 09:20:22+00:00                0
# 3   2023-06-30 09:20:00+00:00                3
# 4   2023-06-30 09:15:22+00:00                3
# ..                        ...              ...
# 994 2023-06-29 07:07:12+00:00               14
# 995 2023-06-29 07:06:59+00:00                0
# 996 2023-06-29 07:06:35+00:00                0
# 997 2023-06-29 07:06:23+00:00                0
# 998 2023-06-29 07:05:59+00:00                1
#
#                                                 Tweets  \
# 0    #ENGvAUS #ENGvsAUS #AUSvENG #AUSvsENG #Adipuru...
# 1    Now Playing!! Book Your Ticket Now!! 🎥🍿🎟️\n@go...
# 2                               @ponilemova #Adipurush
# 3    Adipurush VS 72 Hoorain VS The Kerala Story Co...
# 4               ST: #Adipurush https://t.co/lsGKcgQuKL
# ..                                                 ...
# ...

# %%
# Create a copy of the DataFrame 'df' and assign it to 'df1'
df1 = df.copy()

# %%
# Filter the DataFrame 'df' for tweets in English
df1['english_tweets'] = df[df['Language'] == 'en']['Cleaned_Tweets']

# %%
df1 # Printing the updated DataFrame now
# Out:
#                  Date Created  Number of Likes  \
# 0   2023-06-30 09:21:00+00:00                0
# 1   2023-06-30 09:20:57+00:00                0
# 2   2023-06-30 09:20:22+00:00                0
# 3   2023-06-30 09:20:00+00:00                3
# 4   2023-06-30 09:15:22+00:00                3
# ..                        ...              ...
# 994 2023-06-29 07:07:12+00:00               14
# 995 2023-06-29 07:06:59+00:00                0
# 996 2023-06-29 07:06:35+00:00                0
# 997 2023-06-29 07:06:23+00:00                0
# 998 2023-06-29 07:05:59+00:00                1
#
#                                                 Tweets  \
# 0    #ENGvAUS #ENGvsAUS #AUSvENG #AUSvsENG #Adipuru...
# 1    Now Playing!! Book Your Ticket Now!! 🎥🍿🎟️\n@go...
# 2                               @ponilemova #Adipurush
# 3    Adipurush VS 72 Hoorain VS The Kerala Story Co...
# 4               ST: #Adipurush https://t.co/lsGKcgQuKL
# ..                                                 ...
# ...

# %%
df1 = df1.dropna() # Remove rows with missing values

# %%
df1 # Printing the updated DataFrame now
# Out:
#                  Date Created  Number of Likes  \
# 0   2023-06-30 09:21:00+00:00                0
# 1   2023-06-30 09:20:57+00:00                0
# 3   2023-06-30 09:20:00+00:00                3
# 5   2023-06-30 09:08:27+00:00                1
# 8   2023-06-30 09:04:09+00:00                0
# ..                        ...              ...
# 992 2023-06-29 07:08:02+00:00              146
# 993 2023-06-29 07:07:55+00:00                1
# 994 2023-06-29 07:07:12+00:00               14
# 995 2023-06-29 07:06:59+00:00                0
# 997 2023-06-29 07:06:23+00:00                0
#
#                                                 Tweets  \
# 0    #ENGvAUS #ENGvsAUS #AUSvENG #AUSvsENG #Adipuru...
# 1    Now Playing!! Book Your Ticket Now!! 🎥🍿🎟️\n@go...
# 3    Adipurush VS 72 Hoorain VS The Kerala Story Co...
# 5    This is how the story should be told. @omraut ...
# 8    @VikasAgarwalll Milord says: If my compatriots...
# ..                                                 ...
# ...

# %%
# Extract year, month, and day from the 'Date Created' column and create new columns
df1['Year'] = df1['Date Created'].dt.year
df1['Month'] = df1['Date Created'].dt.month
df1['Day'] = df1['Date Created'].dt.day

# %%
df1 # Printing the updated DataFrame now
# Out:
#                  Date Created  Number of Likes  \
# 0   2023-06-30 09:21:00+00:00                0
# 1   2023-06-30 09:20:57+00:00                0
# 3   2023-06-30 09:20:00+00:00                3
# 5   2023-06-30 09:08:27+00:00                1
# 8   2023-06-30 09:04:09+00:00                0
# ..                        ...              ...
# 992 2023-06-29 07:08:02+00:00              146
# 993 2023-06-29 07:07:55+00:00                1
# 994 2023-06-29 07:07:12+00:00               14
# 995 2023-06-29 07:06:59+00:00                0
# 997 2023-06-29 07:06:23+00:00                0
#
#                                                 Tweets  \
# 0    #ENGvAUS #ENGvsAUS #AUSvENG #AUSvsENG #Adipuru...
# 1    Now Playing!! Book Your Ticket Now!! 🎥🍿🎟️\n@go...
# 3    Adipurush VS 72 Hoorain VS The Kerala Story Co...
# 5    This is how the story should be told. @omraut ...
# 8    @VikasAgarwalll Milord says: If my compatriots...
# ..                                                 ...
# ...

# %%
df1.nunique() # To get the number of unique values in a column of DataFrame
# Out:
# Date Created       521
# Number of Likes    111
# Tweets             520
# Cleaned_Tweets     465
# Language             1
# english_tweets     465
# Year                 1
# Month                1
# Day                  2
# dtype: int64

# %%
df1['Time'] = df1['Date Created'].dt.time # Extract time from the 'Date Created' column

# %%
df1['Tweet_Length'] = df1['english_tweets'].str.len() # Calculate the length of each tweet

# %%
plt.figure(figsize=[15,7],) # Figure/Size for the Graph Image [width: 15 ; height: 10]
plt.title('Count Plot for Day') # Sets the title of the plot
sns.countplot(x = 'Day', data = df1, palette = 'hls') # Creates a count plot for the 'Day' column
plt.xticks(rotation = 90) # Rotates the x-axis labels for better readability
plt.show() # Displays the plot on the screen

# %%
plt.figure(figsize=(15, 6)) # Figure/Size for the Graph Image [width: 15 ; height: 10]
counts = df1['Day'].value_counts() # Counts the occurrences of each value in the 'Day' column
# Creates a pie chart
plt.pie(counts, labels=counts.index, autopct='%1.1f%%', colors=sns.color_palette('hls'))
plt.title('Day') # Sets the title of the plot
plt.show() # Displays the plot on the screen

# %%
import plotly.graph_objects as go # For creating interactive plots

# %%
# Create a bar chart using Plotly to visualize the count of tweets for each day
fig = go.Figure(data=[go.Bar(x=df1['Day'].value_counts().index, y=df1['Day'].value_counts())])
fig.update_layout(
        title= 'Day',
        xaxis_title="Categories",
        yaxis_title="Count"
    )
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
counts = df1['Day'].value_counts() # Counts the occurrences of each value in the 'Day' column
fig = go.Figure(data=[go.Pie(labels=counts.index, values=counts)]) # Creates a pie chart
fig.update_layout(title= 'Day') # Sets the title of the plot
fig.show() # Displays the plot on the screen
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
plt.figure(figsize=(15,6)) # Figure/Size for the Graph Image [width: 15 ; height: 10]
sns.histplot(df1['Tweet_Length'], kde = True, bins = 5, palette = 'hls') # Creates a histogram plot for the 'Tweet_Length' column
plt.title('Tweet Length') # Sets the title of the plot
plt.xticks(rotation = 90) # Rotates the x-axis labels for better readability
plt.show() # Displays the plot on the screen

# %%
# Initialize a SpellChecker object for spell checking tasks
spell = SpellChecker()

# %%
# Function to label sentiment based on polarity score
def label_sentiment(x:float):
    if x < -0.05 : return 'negative'
    if x > 0.35 : return 'positive'
    return 'neutral'

# %%
sia = SIA() # Create an instance of the SentimentIntensityAnalyzer

# %%
# Calculate sentiment for each tweet
df1['sentiment'] = [sia.polarity_scores(x)['compound'] for x in tqdm(df1['english_tweets'])]
# Apply the function to the 'sentiment' column
df1['overall_sentiment'] = df1['sentiment'].apply(label_sentiment);
# Out:
#   0%|          | 0/522 [00:00<?, ?it/s]

# %%
df1 # Printing the updated DataFrame now
# Out:
#                  Date Created  Number of Likes  \
# 0   2023-06-30 09:21:00+00:00                0
# 1   2023-06-30 09:20:57+00:00                0
# 3   2023-06-30 09:20:00+00:00                3
# 5   2023-06-30 09:08:27+00:00                1
# 8   2023-06-30 09:04:09+00:00                0
# ..                        ...              ...
# 992 2023-06-29 07:08:02+00:00              146
# 993 2023-06-29 07:07:55+00:00                1
# 994 2023-06-29 07:07:12+00:00               14
# 995 2023-06-29 07:06:59+00:00                0
# 997 2023-06-29 07:06:23+00:00                0
#
#                                                 Tweets  \
# 0    #ENGvAUS #ENGvsAUS #AUSvENG #AUSvsENG #Adipuru...
# 1    Now Playing!! Book Your Ticket Now!! 🎥🍿🎟️\n@go...
# 3    Adipurush VS 72 Hoorain VS The Kerala Story Co...
# 5    This is how the story should be told. @omraut ...
# 8    @VikasAgarwalll Milord says: If my compatriots...
# ..                                                 ...
# ...

# %%
counts = df1['overall_sentiment'].value_counts() # Counts the occurrences of each value in the 'overall_sentiment' column
fig = go.Figure(data=[go.Pie(labels=counts.index, values=counts)]) # Creates a pie chart
fig.update_layout(title= 'Overall Sentiment') # Sets the title of the plot
fig.show() # Displays the plot on the screen
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df1['overall_sentiment'].unique() # To get the unique values in a column of DataFrame
# Out:
# array(['neutral', 'positive', 'negative'], dtype=object)

# %%
df1['overall_sentiment'].value_counts() # To get the count of unique values in a column of DataFrame
# Out:
# overall_sentiment
# neutral     232
# negative    171
# positive    119
# Name: count, dtype: int64

# %%
label_data = df1['overall_sentiment'].value_counts() # Counts the occurrences of each value in the 'overall_sentiment' column

explode = (0.1, 0.1, 0.1) # Explodes the first slice
plt.figure(figsize=(14, 10)) # Figure/Size for the Graph Image [width: 15 ; height: 10]
# Create the pie chart
patches, texts, pcts = plt.pie(label_data,
                               labels = label_data.index,
                               colors = ['blue', 'red', 'green'],
                               pctdistance = 0.65,
                               shadow = True,
                               startangle = 90,
                               explode = explode,
                               autopct = '%1.1f%%',
                               textprops={ 'fontsize': 25,
                                           'color': 'black',
                                           'weight': 'bold',
                                           'family': 'serif' })
plt.setp(pcts, color='white') # Sets the color of the text labels to white

hfont = {'fontname':'serif', 'weight': 'bold'} # Sets the font style for the title
# Set the title of the pie chart
plt.title('Label', size=20, **hfont)

centre_circle = plt.Circle((0,0),0.40,fc='white') # Creates a circle at the center of the pie chart
fig = plt.gcf() # Get current figure
# The following line was incorrectly indented
fig.gca().add_artist(centre_circle)
plt.show() # Displays the plot on the screen

# %%
# Create a bar chart using Plotly to visualize the count of each overall sentiment
fig = go.Figure(data=[go.Bar(x=df1['overall_sentiment'].value_counts().index, y=df1['overall_sentiment'].value_counts())])
fig.update_layout(
        title= 'Overall Sentiment',
        xaxis_title="Categories",
        yaxis_title="Count"
    )
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
